# %%
import json
import urllib2

url = urllib2.urlopen("https://nl.wikipedia.org/wiki/Amsterdam")
html = url.read()

print html

baseurl = "https://eng.wikipedia.org/w/api.php?"
action = "action=query"
title = "titles=Amsterdam"
content = "prop=revision&rvprop=content"
dataformat = "format=json"

url = "%s%s%s%s%s"% (baseurl, acion, title, content, dataformat)

html = urllib2.openurl(url).read
wikijson = json.loads(html)
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" lang="nl" dir="ltr">
# <head>
# <meta charset="UTF-8"/>
# <title>Amsterdam - Wikipedia</title>
# <script>document.documentElement.className = document.documentElement.className.replace( /(^|\s)client-nojs(\s|$)/, "$1client-js$2" );</script>
# ...
